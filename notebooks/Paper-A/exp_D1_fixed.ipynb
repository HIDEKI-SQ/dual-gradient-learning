# %% [markdown]
# # Exp D1 (FIXED): Non-Oracle Value Signal (Noise=40%)
#
# ## 修正版 - DataLoaderインデックス問題を解決
#
# ### 実験条件
# - Noise: **40%**
# - Clean ratio: 1%, 5%, 10%
# - λ: 0.0, 0.2, 0.3, 0.4, 0.6
# - Seeds: 0, 1, 2
#
# ### 実効runs数: 39 runs

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
SAVE_DIR = '/content/drive/MyDrive/dual-gradient-results/exp_D1_fixed'
os.makedirs(SAVE_DIR, exist_ok=True)
print(f'Save directory: {SAVE_DIR}')

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset
from torch.nn.utils import parameters_to_vector
import torchvision
import torchvision.transforms as transforms
import numpy as np
import json
import time

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

if torch.cuda.is_available():
    torch.backends.cudnn.benchmark = True
    torch.backends.cudnn.deterministic = False
    print(f'GPU: {torch.cuda.get_device_name(0)}')
print(f'Device: {device}')

# %%
class IndexedDataset(Dataset):
    def __init__(self, dataset):
        self.dataset = dataset
    def __getitem__(self, idx):
        img, label = self.dataset[idx]
        return img, label, idx
    def __len__(self):
        return len(self.dataset)

class BasicBlock(nn.Module):
    expansion = 1
    def __init__(self, in_planes, planes, stride=1):
        super().__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, 3, stride, 1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, 3, 1, 1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, planes, 1, stride, bias=False),
                nn.BatchNorm2d(planes))
    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        return F.relu(out)

class ResNet18(nn.Module):
    def __init__(self, num_classes=10):
        super().__init__()
        self.in_planes = 64
        self.conv1 = nn.Conv2d(3, 64, 3, 1, 1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(64, 2, 1)
        self.layer2 = self._make_layer(128, 2, 2)
        self.layer3 = self._make_layer(256, 2, 2)
        self.layer4 = self._make_layer(512, 2, 2)
        self.linear = nn.Linear(512, num_classes)
    def _make_layer(self, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for s in strides:
            layers.append(BasicBlock(self.in_planes, planes, s))
            self.in_planes = planes
        return nn.Sequential(*layers)
    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.adaptive_avg_pool2d(out, 1)
        out = out.view(out.size(0), -1)
        return self.linear(out)

# %%
BATCH_SIZE = 256
NUM_WORKERS = 4
EPOCHS = 100
LR = 0.1
NOISE_RATE = 0.4  # D1: 40% noise

CLEAN_RATIOS = [0.01, 0.05, 0.10]
LAMBDAS = [0.0, 0.2, 0.3, 0.4, 0.6]
SEEDS = [0, 1, 2]

def set_seed(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    np.random.seed(seed)

def load_cifar10():
    transform_train = transforms.Compose([
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))])
    transform_test = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))])
    trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train)
    testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_test)
    return trainset, testset

def get_data_loaders(trainset, testset):
    indexed_trainset = IndexedDataset(trainset)
    train_loader = DataLoader(indexed_trainset, batch_size=BATCH_SIZE, shuffle=True,
                              num_workers=NUM_WORKERS, pin_memory=True, persistent_workers=True, drop_last=True)
    test_loader = DataLoader(testset, batch_size=BATCH_SIZE, shuffle=False,
                             num_workers=NUM_WORKERS, pin_memory=True, persistent_workers=True)
    return train_loader, test_loader

def inject_noise(labels, noise_rate, seed):
    np.random.seed(seed + 1000)
    noisy_labels = labels.copy()
    n_noisy = int(noise_rate * len(labels))
    noisy_indices = np.random.choice(len(labels), n_noisy, replace=False)
    for idx in noisy_indices:
        choices = [i for i in range(10) if i != labels[idx]]
        noisy_labels[idx] = np.random.choice(choices)
    return noisy_labels

def select_clean_subset(n_samples, clean_ratio, seed):
    np.random.seed(seed + 2000)
    n_clean = int(clean_ratio * n_samples)
    return set(np.random.choice(n_samples, n_clean, replace=False))

print(f'Noise rate: {NOISE_RATE}')

# %%
def evaluate(model, test_loader):
    model.eval()
    correct = total = 0
    with torch.no_grad():
        for inputs, targets in test_loader:
            inputs, targets = inputs.to(device, non_blocking=True), targets.to(device, non_blocking=True)
            outputs = model(inputs)
            _, predicted = outputs.max(1)
            total += targets.size(0)
            correct += predicted.eq(targets).sum().item()
    return correct / total

def train_ce_baseline(model, train_loader, test_loader, noisy_labels):
    optimizer = optim.SGD(model.parameters(), lr=LR, momentum=0.9, weight_decay=5e-4)
    scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones=[50, 75], gamma=0.1)
    criterion = nn.CrossEntropyLoss()
    noisy_labels_tensor = torch.tensor(noisy_labels, device=device)
    best_acc = 0
    
    for epoch in range(EPOCHS):
        model.train()
        for inputs, _, indices in train_loader:
            inputs = inputs.to(device, non_blocking=True)
            indices = indices.to(device, non_blocking=True)
            batch_labels = noisy_labels_tensor[indices]
            optimizer.zero_grad()
            loss = criterion(model(inputs), batch_labels)
            loss.backward()
            optimizer.step()
        scheduler.step()
        if (epoch + 1) % 10 == 0:
            best_acc = max(best_acc, evaluate(model, test_loader))
    final_acc = evaluate(model, test_loader)
    return final_acc, max(best_acc, final_acc)

def train_dual_gradient_non_oracle(model, train_loader, test_loader, clean_labels, noisy_labels, clean_indices, lam):
    optimizer = optim.SGD(model.parameters(), lr=LR, momentum=0.9, weight_decay=5e-4)
    scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones=[50, 75], gamma=0.1)
    criterion = nn.CrossEntropyLoss()
    clean_labels_tensor = torch.tensor(clean_labels, device=device)
    noisy_labels_tensor = torch.tensor(noisy_labels, device=device)
    K, cached_value_grad, global_step, best_acc = 16, None, 0, 0
    
    for epoch in range(EPOCHS):
        model.train()
        for inputs, _, indices in train_loader:
            inputs = inputs.to(device, non_blocking=True)
            indices_cpu = indices.numpy()
            indices = indices.to(device, non_blocking=True)
            batch_noisy = noisy_labels_tensor[indices]
            
            optimizer.zero_grad()
            loss_struct = criterion(model(inputs), batch_noisy)
            loss_struct.backward()
            g_struct = parameters_to_vector([p.grad for p in model.parameters()]).clone()
            
            if global_step % K == 0 or cached_value_grad is None:
                clean_mask = [i for i, idx in enumerate(indices_cpu) if idx in clean_indices]
                if len(clean_mask) > 0:
                    optimizer.zero_grad()
                    clean_inputs = inputs[clean_mask]
                    clean_targets = clean_labels_tensor[indices[clean_mask]]
                    loss_value = criterion(model(clean_inputs), clean_targets)
                    loss_value.backward()
                    cached_value_grad = parameters_to_vector([p.grad for p in model.parameters()]).clone()
                elif cached_value_grad is None:
                    cached_value_grad = g_struct.clone()
            
            g_struct_norm = g_struct / (g_struct.norm() + 1e-12)
            g_value_norm = cached_value_grad / (cached_value_grad.norm() + 1e-12)
            g_mix = (1 - lam) * g_struct_norm + lam * g_value_norm
            
            optimizer.zero_grad()
            idx = 0
            for p in model.parameters():
                numel = p.numel()
                p.grad = g_mix[idx:idx+numel].view(p.shape).clone()
                idx += numel
            optimizer.step()
            global_step += 1
        scheduler.step()
        if (epoch + 1) % 10 == 0:
            best_acc = max(best_acc, evaluate(model, test_loader))
    final_acc = evaluate(model, test_loader)
    return final_acc, max(best_acc, final_acc)

# %%
n_ce_runs = len(SEEDS)
n_dg_runs = len(CLEAN_RATIOS) * (len(LAMBDAS) - 1) * len(SEEDS)
total_runs = n_ce_runs + n_dg_runs
print(f'Total runs: {total_runs}')

# %%
trainset, testset = load_cifar10()
clean_labels = np.array(trainset.targets)
train_loader, test_loader = get_data_loaders(trainset, testset)
print(f'Data loaded.')

print('Verifying IndexedDataset...')
sample_batch = next(iter(train_loader))
print(f'  ✓ Batch: inputs{list(sample_batch[0].shape)}, labels{list(sample_batch[1].shape)}, indices{list(sample_batch[2].shape)}')

print('Warming up GPU...')
warmup_model = ResNet18().to(device)
for _ in range(20):
    _ = warmup_model(torch.randn(BATCH_SIZE, 3, 32, 32, device=device))
del warmup_model
torch.cuda.empty_cache()
print('Warmup complete.')

# %%
results = []
checkpoint_file = f'{SAVE_DIR}/checkpoint.json'
completed_ce, completed_dg = set(), set()

if os.path.exists(checkpoint_file):
    with open(checkpoint_file, 'r') as f:
        results = json.load(f)
    for r in results:
        if r['lambda'] == 0.0: completed_ce.add(r['seed'])
        else: completed_dg.add((r['clean_ratio'], r['lambda'], r['seed']))
    print(f'Checkpoint loaded: {len(completed_ce)} CE, {len(completed_dg)} DG')

ce_cache = {}
run_counter = 0
exp_start = time.time()

print('\n' + '='*60)
print('PHASE 1: CE BASELINE')
print('='*60)

for seed in SEEDS:
    run_counter += 1
    if seed in completed_ce:
        for r in results:
            if r['lambda'] == 0.0 and r['seed'] == seed:
                ce_cache[seed] = r
                break
        print(f'[{run_counter}/{total_runs}] CE seed={seed} - LOADED')
        continue
    
    print(f'\n[{run_counter}/{total_runs}] CE seed={seed}')
    t0 = time.time()
    set_seed(seed)
    noisy_labels = inject_noise(clean_labels, NOISE_RATE, seed)
    model = ResNet18().to(device)
    final_acc, best_acc = train_ce_baseline(model, train_loader, test_loader, noisy_labels)
    elapsed = time.time() - t0
    
    ce_cache[seed] = {'test_acc': final_acc, 'test_error': 1-final_acc, 'best_test_error': 1-best_acc, 'time_seconds': elapsed}
    
    for cr in CLEAN_RATIOS:
        results.append({'experiment': 'exp_D1_fixed', 'noise_rate': NOISE_RATE, 'clean_ratio': cr,
                        'lambda': 0.0, 'seed': seed, 'test_acc': final_acc, 'test_error': 1-final_acc,
                        'best_test_error': 1-best_acc, 'time_seconds': elapsed})
    
    with open(checkpoint_file, 'w') as f: json.dump(results, f, indent=2)
    print(f'  Error: {1-final_acc:.4f} | Best: {1-best_acc:.4f} | Time: {elapsed/60:.1f} min')

print('\n' + '='*60)
print('PHASE 2: DUAL-GRADIENT')
print('='*60)

for cr in CLEAN_RATIOS:
    for lam in LAMBDAS:
        if lam == 0.0: continue
        for seed in SEEDS:
            run_counter += 1
            if (cr, lam, seed) in completed_dg:
                print(f'[{run_counter}/{total_runs}] cr={cr*100:.0f}% λ={lam} seed={seed} - SKIPPED')
                continue
            
            print(f'\n[{run_counter}/{total_runs}] cr={cr*100:.0f}% λ={lam} seed={seed}')
            t0 = time.time()
            set_seed(seed)
            noisy_labels = inject_noise(clean_labels, NOISE_RATE, seed)
            clean_indices = select_clean_subset(len(clean_labels), cr, seed)
            model = ResNet18().to(device)
            final_acc, best_acc = train_dual_gradient_non_oracle(model, train_loader, test_loader, clean_labels, noisy_labels, clean_indices, lam)
            elapsed = time.time() - t0
            
            results.append({'experiment': 'exp_D1_fixed', 'noise_rate': NOISE_RATE, 'clean_ratio': cr,
                            'lambda': lam, 'seed': seed, 'test_acc': final_acc, 'test_error': 1-final_acc,
                            'best_test_error': 1-best_acc, 'time_seconds': elapsed})
            
            with open(checkpoint_file, 'w') as f: json.dump(results, f, indent=2)
            print(f'  Error: {1-final_acc:.4f} | Best: {1-best_acc:.4f} | Time: {elapsed/60:.1f} min')

print(f'\nTotal time: {(time.time()-exp_start)/3600:.2f} hours')

# %%
import pandas as pd
with open(f'{SAVE_DIR}/exp_D1_fixed_results.json', 'w') as f:
    json.dump(results, f, indent=2)
df = pd.DataFrame(results)
summary = df.groupby(['clean_ratio', 'lambda']).agg({'test_error': ['mean', 'std', 'count']}).round(4)
print(summary)
summary.to_csv(f'{SAVE_DIR}/exp_D1_fixed_summary.csv')

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(10, 6))
for cr in CLEAN_RATIOS:
    df_cr = df[df['clean_ratio'] == cr]
    g = df_cr.groupby('lambda')['test_error'].agg(['mean', 'std'])
    ax.errorbar(g.index, g['mean'], yerr=g['std'], marker='o', capsize=5, label=f'{cr*100:.0f}% clean', linewidth=2, markersize=10)
ax.set_xlabel('λ', fontsize=13)
ax.set_ylabel('Test Error', fontsize=13)
ax.set_title(f'Non-Oracle Dual-Gradient (Noise={int(NOISE_RATE*100)}%) - FIXED', fontsize=14, fontweight='bold')
ax.legend()
ax.grid(alpha=0.3)
plt.tight_layout()
plt.savefig(f'{SAVE_DIR}/exp_D1_fixed_plot.png', dpi=300, bbox_inches='tight')
plt.show()
